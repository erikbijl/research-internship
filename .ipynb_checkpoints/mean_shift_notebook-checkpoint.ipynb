# %%
#example from http://efavdb.com/mean-shift/
import numpy as np
from sklearn.cluster import MeanShift, estimate_bandwidth
from sklearn.datasets.samples_generator import make_blobs
import matplotlib.pyplot as plt
from itertools import cycle
from PIL import Image

# %%
image = Image.open('lenna.jpg')
width, height = image.size
new_width = round(width/1)
new_height = round(height/1)
image = image.resize((new_width, new_height), Image.ANTIALIAS)
plt.imshow(image)

# %%
image = np.array(image)
image.shape
# Out:
# (220, 220, 4)

# %%
#Need to convert image into feature array based
#on rgb intensities
flat_image=np.reshape(image, [-1, 3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-ce987feee9d6> in <module>()
#       1 #Need to convert image into feature array based
#       2 #on rgb intensities
# ----> 3 flat_image=np.reshape(image, [-1, 3])
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     255            [5, 6]])
#     256     """
# --> 257     return _wrapfunc(a, 'reshape', newshape, order=order)
#     258
#     259
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      50 def _wrapfunc(obj, method, *args, **kwds):
#      51     try:
# ---> 52         return getattr(obj, method)(*args, **kwds)
#      53
#      54     # An AttributeError occurs if the object does not have
#
# ValueError: cannot reshape array of size 193600 into shape (3)

# %%
#Estimate bandwidth
bandwidth2 = estimate_bandwidth(flat_image, quantile=.2, n_samples=500)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-27f300415458> in <module>()
#       1 #Estimate bandwidth
# ----> 2 bandwidth2 = estimate_bandwidth(flat_image, quantile=.2, n_samples=500)
#
# NameError: name 'flat_image' is not defined

# %%
ms = MeanShift(bandwidth2, bin_seeding=True)
ms.fit(flat_image)
labels=ms.labels_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-b954cffd9f8b> in <module>()
# ----> 1 ms = MeanShift(bandwidth2, bin_seeding=True)
#       2 ms.fit(flat_image)
#       3 labels=ms.labels_
#
# NameError: name 'bandwidth2' is not defined

# %%
# Plot image vs segmented image
plt.imshow(np.reshape(labels, [new_height, new_width]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-2b17b90313bb> in <module>()
#       1 # Plot image vs segmented image
# ----> 2 plt.imshow(np.reshape(labels, [new_height, new_width]))
#
# NameError: name 'labels' is not defined
